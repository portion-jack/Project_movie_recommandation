# %%
import pandas as pd
import datetime
from utils.get_data import get_data

from recommandation.recommand_general import recommand_general
from recommandation.recommand_with_genre import recommand_with_genres

# %%
# get merged data
main_raw=get_data()

# using data after 2009
df_recent=main_raw[main_raw['year'] > 2010]

# using data that has more than 5 reviews
using_movies=df_recent.value_counts('title')[df_recent.value_counts('title') > 5].index
df_main=df_recent[df_recent['title'].isin(using_movies)].reset_index(drop=True)

# %%
df_main['genres'].unique()
# Out:
# array(['Adventure|Animation|Children|Comedy|Fantasy',
#        'Action|Crime|Thriller', 'Mystery|Thriller',
#        'Crime|Mystery|Thriller', 'Action|Comedy|Horror|Thriller',
#        'Action|Drama|War', 'Action|Romance|Western', 'Comedy',
#        'Adventure|Comedy', 'Comedy|Drama', 'Action|Adventure|Sci-Fi',
#        'Comedy|Crime|Drama|Thriller', 'Comedy|Drama|Romance|War',
#        'Adventure|Children|Romance', 'Action|Comedy|Crime|Fantasy',
#        'Thriller', 'Action|Adventure|Sci-Fi|Thriller', 'Drama|War',
#        'Adventure|Drama|Western', 'Crime|Horror|Thriller',
#        'Animation|Children|Fantasy|Musical',
#        'Action|Adventure|Mystery|Thriller',
#        'Adventure|Animation|Children|Fantasy|Musical',
#        'Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi',
#        'Action|Adventure|Thriller', 'Action|Adventure|Romance|Thriller',
#        'Adventure|Children|Fantasy|Musical', 'Drama|Mystery',
#        'Animation|Children|Drama|Musical',
# ...

# %%
recommand_with_genres(df_main,5,['Animation','IMAX'])
# Out:
#                                iid       est                            title  \
# 0            Lion King, The (1994)  4.080034            Lion King, The (1994)
# 1               Toy Story 3 (2010)  4.076897               Toy Story 3 (2010)
# 2                   Tangled (2010)  3.951914                   Tangled (2010)
# 3      Beauty and the Beast (1991)  3.931632      Beauty and the Beast (1991)
# 4  How to Train Your Dragon (2010)  3.923750  How to Train Your Dragon (2010)
#
#                                               genres
# 0  [Adventure, Animation, Children, Drama, Musica...
# 1  [Adventure, Animation, Children, Comedy, Fanta...
# 2  [Animation, Children, Comedy, Fantasy, Musical...
# 3  [Animation, Children, Fantasy, Musical, Romanc...
# 4    [Adventure, Animation, Children, Fantasy, IMAX]
